# %%
import pandas as pd

# %% [markdown]
# q1

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
df = pd.read_csv("car_fuel_efficiency_2026.csv")

# %% [markdown]
# q2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_year           10000 non-null  int64
#  1   origin               10000 non-null  str
#  2   fuel_type            10000 non-null  str
#  3   drivetrain           10000 non-null  str
#  4   num_doors            10000 non-null  int64
#  5   engine_displacement  10000 non-null  int64
#  6   num_cylinders        10000 non-null  int64
#  7   horsepower           9123 non-null   float64
#  8   vehicle_weight       10000 non-null  int64
#  9   acceleration         9736 non-null   float64
#  10  fuel_efficiency_mpg  10000 non-null  float64
# dtypes: float64(3), int64(5), str(3)
# memory usage: 859.5 KB

# %%
records = df.shape[0]
print(records)
# Out:
# 10000

# %% [markdown]
# q3

# %%
df['fuel_type'].unique()
# Out:
# <StringArray>
# ['Gasoline', 'Diesel', 'Hybrid']
# Length: 3, dtype: str

# %% [markdown]
# q4

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower               0
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# q5

# %%
solo_asia = df[df["origin"] == "Asia"]

# %%
solo_asia["fuel_efficiency_mpg"].max()
# Out:
# np.float64(41.2)

# %%
df.loc[df["origin"] == "Asia", "fuel_efficiency_mpg"].max()
# Out:
# np.float64(41.2)

# %% [markdown]
# q6

# %%
df["horsepower"].median()
# Out:
# np.float64(254.0)

# %%
moda = df["horsepower"].mode()[0]
moda
# Out:
# np.float64(252.0)

# %%
df["horsepower"] = df["horsepower"].fillna(moda)

# %%
df["horsepower"].median()
# Out:
# np.float64(252.0)

# %% [markdown]
# it decrease

# %% [markdown]
# q7

# %%
X = df.loc[df["origin"] == "Asia", ["vehicle_weight", "model_year"]][:7]

# %%
import numpy as np

# %%
X
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %%
X.T
# Out:
#                   2     6     8     10    15    16    22
# vehicle_weight  4240  4310  4230  4420  3950  4750  4450
# model_year      1996  1992  1997  1978  2007  2021  2019

# %%
XTX = X.T @ X

XTX_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = XTX_inv @ X.T @ y

resultado_final = np.sum(w)
print(resultado_final)
# Out:
# 0.3691969690492549
